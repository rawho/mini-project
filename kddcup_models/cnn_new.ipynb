# %%
import pandas as pd
from tensorflow.keras.utils import get_file
import pandas as pd
import os
import numpy as np
from sklearn import metrics
from scipy.stats import zscore
import matplotlib.pyplot as plt
import matplotlib
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import Normalizer
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Lambda
from keras.layers import Embedding
from keras.layers import Convolution1D,MaxPooling1D, Flatten
from keras.datasets import imdb
from keras import backend as K
import pandas as pd
from keras.models import Sequential
from keras.layers import Convolution1D, Dense, Dropout, Flatten, MaxPooling1D
from keras.utils import np_utils
import numpy as np
import h5py
from keras import callbacks
from keras.layers import LSTM, GRU, SimpleRNN
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger

# %%
pd.set_option('display.max_columns', 6)
pd.set_option('display.max_rows', 5)

try:
    path = get_file('kdd-with-columns.csv', origin=\
    'https://github.com/jeffheaton/jheaton-ds2/raw/main/'\
    'kdd-with-columns.csv',archive_format=None)
except:
    print('Error downloading')
    raise
    
print(path) 

# Origional file: http://kdd.ics.uci.edu/databases/kddcup99/kddcup99.html
df = pd.read_csv(path)

print("Read {} rows.".format(len(df)))
# df = df.sample(frac=0.1, replace=False) # Uncomment this line to 
# sample only 10% of the dataset
df.dropna(inplace=True,axis=1) 
# For now, just drop NA's (rows with missing values)


# display 5 rows
pd.set_option('display.max_columns', 5)
pd.set_option('display.max_rows', 5)
df
# Out:
# /root/.keras/datasets/kdd-with-columns.csv
# Read 494021 rows.
#         duration protocol_type  ... dst_host_srv_rerror_rate  outcome
# 0              0           tcp  ...                      0.0  normal.
# 1              0           tcp  ...                      0.0  normal.
# ...          ...           ...  ...                      ...      ...
# 494019         0           tcp  ...                      0.0  normal.
# 494020         0           tcp  ...                      0.0  normal.
#
# [494021 rows x 42 columns]

# %%
# Encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd
    
# Encode text values to dummy variables(i.e. [1,0,0],
# [0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = f"{name}-{x}"
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)

# Now encode the feature vector

pd.set_option('display.max_columns', 6)
pd.set_option('display.max_rows', 5)

for name in df.columns:
  if name == 'outcome':
    pass
  elif name in ['protocol_type','service','flag','land','logged_in',
                'is_host_login','is_guest_login']:
    encode_text_dummy(df,name)
  else:
    encode_numeric_zscore(df,name)    

# display 5 rows

df.dropna(inplace=True,axis=1)
df[0:5]


# Convert to numpy - Classification
x_columns = df.columns.drop('outcome')
x = df[x_columns].values
dummies = pd.get_dummies(df['outcome']) # Classification
outcomes = dummies.columns
num_classes = len(outcomes)
y = dummies.values

# %%
df.groupby('outcome')['outcome'].count()
# Out:
# outcome
# back.               2203
# buffer_overflow.      30
#                     ...
# warezclient.        1020
# warezmaster.          20
# Name: outcome, Length: 23, dtype: int64

# %%
import pandas as pd
import io
import requests
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

# Create a test/train split.  25% test
# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, random_state=42)

# %%
cnn = Sequential()
cnn.add(Convolution1D(64, 2, padding='same',activation="relu",input_shape=(120, 1)))
cnn.add(MaxPooling1D(pool_size=(2)))
cnn.add(Flatten())
cnn.add(Dense(128, activation="relu"))
cnn.add(Dropout(0.5))
cnn.add(Dense(23, activation="softmax"))

# %%
cnn.compile(loss="categorical_crossentropy", optimizer="adam",metrics=['accuracy'])
checkpointer = callbacks.ModelCheckpoint(filepath="checkpoint/cnn/checkpoint-{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='val_accuracy',mode='max')
csv_logger = CSVLogger('logs/cnnanalysis.csv',separator=',', append=False)
history = cnn.fit(x_train, y_train, epochs=50,validation_data=(x_test, y_test),callbacks=[checkpointer,csv_logger],verbose=2)
cnn.save("results/cnn/cnn_model.h5")
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.99849, saving model to checkpoint/cnn/checkpoint-01.hdf5
# 11579/11579 - 125s - loss: 0.0224 - accuracy: 0.9961 - val_loss: 0.0068 - val_accuracy: 0.9985 - 125s/epoch - 11ms/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.99849 to 0.99855, saving model to checkpoint/cnn/checkpoint-02.hdf5
# 11579/11579 - 127s - loss: 0.0111 - accuracy: 0.9980 - val_loss: 0.0058 - val_accuracy: 0.9986 - 127s/epoch - 11ms/step
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.99855 to 0.99879, saving model to checkpoint/cnn/checkpoint-03.hdf5
# 11579/11579 - 127s - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.0048 - val_accuracy: 0.9988 - 127s/epoch - 11ms/step
# Epoch 4/50
#
# Epoch 4: val_accuracy improved from 0.99879 to 0.99901, saving model to checkpoint/cnn/checkpoint-04.hdf5
# 11579/11579 - 117s - loss: 0.0087 - accuracy: 0.9985 - val_loss: 0.0045 - val_accuracy: 0.9990 - 117s/epoch - 10ms/step
# Epoch 5/50
#
# Epoch 5: val_accuracy did not improve from 0.99901
# 11579/11579 - 127s - loss: 0.0097 - accuracy: 0.9986 - val_loss: 0.0064 - val_accuracy: 0.9988 - 127s/epoch - 11ms/step
# Epoch 6/50
#
# Epoch 6: val_accuracy improved from 0.99901 to 0.99912, saving model to checkpoint/cnn/checkpoint-06.hdf5
# 11579/11579 - 119s - loss: 0.0076 - accuracy: 0.9988 - val_loss: 0.0039 - val_accuracy: 0.9991 - 119s/epoch - 10ms/step
# Epoch 7/50
#
# Epoch 7: val_accuracy did not improve from 0.99912
# 11579/11579 - 126s - loss: 0.0071 - accuracy: 0.9989 - val_loss: 0.0043 - val_accuracy: 0.9991 - 126s/epoch - 11ms/step
# Epoch 8/50
#
# Epoch 8: val_accuracy did not improve from 0.99912
# 11579/11579 - 129s - loss: 0.0060 - accuracy: 0.9988 - val_loss: 0.0041 - val_accuracy: 0.9991 - 129s/epoch - 11ms/step
# Epoch 9/50
#
# Epoch 9: val_accuracy improved from 0.99912 to 0.99917, saving model to checkpoint/cnn/checkpoint-09.hdf5
# 11579/11579 - 126s - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.0033 - val_accuracy: 0.9992 - 126s/epoch - 11ms/step
# Epoch 10/50
#
# Epoch 10: val_accuracy did not improve from 0.99917
# 11579/11579 - 117s - loss: 0.0062 - accuracy: 0.9989 - val_loss: 0.0050 - val_accuracy: 0.9989 - 117s/epoch - 10ms/step
# Epoch 11/50
#
# Epoch 11: val_accuracy improved from 0.99917 to 0.99919, saving model to checkpoint/cnn/checkpoint-11.hdf5
# 11579/11579 - 117s - loss: 0.0064 - accuracy: 0.9990 - val_loss: 0.0038 - val_accuracy: 0.9992 - 117s/epoch - 10ms/step
# Epoch 12/50
#
# Epoch 12: val_accuracy improved from 0.99919 to 0.99923, saving model to checkpoint/cnn/checkpoint-12.hdf5
# 11579/11579 - 126s - loss: 0.0058 - accuracy: 0.9989 - val_loss: 0.0041 - val_accuracy: 0.9992 - 126s/epoch - 11ms/step
# Epoch 13/50
#
# Epoch 13: val_accuracy improved from 0.99923 to 0.99930, saving model to checkpoint/cnn/checkpoint-13.hdf5
# 11579/11579 - 117s - loss: 0.0051 - accuracy: 0.9990 - val_loss: 0.0032 - val_accuracy: 0.9993 - 117s/epoch - 10ms/step
# Epoch 14/50
#
# Epoch 14: val_accuracy did not improve from 0.99930
# 11579/11579 - 118s - loss: 0.0063 - accuracy: 0.9990 - val_loss: 0.0044 - val_accuracy: 0.9989 - 118s/epoch - 10ms/step
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.99930
# 11579/11579 - 126s - loss: 0.0069 - accuracy: 0.9990 - val_loss: 0.0036 - val_accuracy: 0.9993 - 126s/epoch - 11ms/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.99930
# 11579/11579 - 123s - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.0051 - val_accuracy: 0.9992 - 123s/epoch - 11ms/step
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.99930
# 11579/11579 - 123s - loss: 0.0069 - accuracy: 0.9990 - val_loss: 0.0036 - val_accuracy: 0.9992 - 123s/epoch - 11ms/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.99930
# 11579/11579 - 128s - loss: 0.0059 - accuracy: 0.9991 - val_loss: 0.0052 - val_accuracy: 0.9991 - 128s/epoch - 11ms/step
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.99930
# 11579/11579 - 118s - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.0036 - val_accuracy: 0.9993 - 118s/epoch - 10ms/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.99930
# 11579/11579 - 119s - loss: 0.0064 - accuracy: 0.9991 - val_loss: 0.0042 - val_accuracy: 0.9992 - 119s/epoch - 10ms/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.99930
# 11579/11579 - 127s - loss: 0.0051 - accuracy: 0.9991 - val_loss: 0.0038 - val_accuracy: 0.9991 - 127s/epoch - 11ms/step
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.99930
# 11579/11579 - 126s - loss: 0.0054 - accuracy: 0.9990 - val_loss: 0.0045 - val_accuracy: 0.9991 - 126s/epoch - 11ms/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.99930
# 11579/11579 - 117s - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.0036 - val_accuracy: 0.9993 - 117s/epoch - 10ms/step
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.99930
# 11579/11579 - 118s - loss: 0.0069 - accuracy: 0.9990 - val_loss: 0.0040 - val_accuracy: 0.9992 - 118s/epoch - 10ms/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.99930
# 11579/11579 - 127s - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.0035 - val_accuracy: 0.9992 - 127s/epoch - 11ms/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.99930
# 11579/11579 - 126s - loss: 0.0059 - accuracy: 0.9991 - val_loss: 0.0046 - val_accuracy: 0.9992 - 126s/epoch - 11ms/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.99930
# 11579/11579 - 128s - loss: 0.0061 - accuracy: 0.9991 - val_loss: 0.0038 - val_accuracy: 0.9993 - 128s/epoch - 11ms/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.99930
# 11579/11579 - 119s - loss: 0.0057 - accuracy: 0.9991 - val_loss: 0.0041 - val_accuracy: 0.9992 - 119s/epoch - 10ms/step
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.99930
# 11579/11579 - 127s - loss: 0.0073 - accuracy: 0.9991 - val_loss: 0.0039 - val_accuracy: 0.9993 - 127s/epoch - 11ms/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.99930
# 11579/11579 - 118s - loss: 0.0069 - accuracy: 0.9990 - val_loss: 0.0035 - val_accuracy: 0.9993 - 118s/epoch - 10ms/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.99930
# 11579/11579 - 129s - loss: 0.0068 - accuracy: 0.9990 - val_loss: 0.0060 - val_accuracy: 0.9991 - 129s/epoch - 11ms/step
# Epoch 32/50
#
# Epoch 32: val_accuracy improved from 0.99930 to 0.99933, saving model to checkpoint/cnn/checkpoint-32.hdf5
# 11579/11579 - 119s - loss: 0.0070 - accuracy: 0.9990 - val_loss: 0.0042 - val_accuracy: 0.9993 - 119s/epoch - 10ms/step
# Epoch 33/50
#
# Epoch 33: val_accuracy improved from 0.99933 to 0.99936, saving model to checkpoint/cnn/checkpoint-33.hdf5
# 11579/11579 - 127s - loss: 0.0092 - accuracy: 0.9991 - val_loss: 0.0044 - val_accuracy: 0.9994 - 127s/epoch - 11ms/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.99936
# 11579/11579 - 120s - loss: 0.0083 - accuracy: 0.9990 - val_loss: 0.0062 - val_accuracy: 0.9992 - 120s/epoch - 10ms/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.99936
# 11579/11579 - 127s - loss: 0.0072 - accuracy: 0.9991 - val_loss: 0.0038 - val_accuracy: 0.9992 - 127s/epoch - 11ms/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.99936
# 11579/11579 - 126s - loss: 0.0074 - accuracy: 0.9991 - val_loss: 0.0049 - val_accuracy: 0.9991 - 126s/epoch - 11ms/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.99936
# 11579/11579 - 116s - loss: 0.0104 - accuracy: 0.9991 - val_loss: 0.0050 - val_accuracy: 0.9992 - 116s/epoch - 10ms/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.99936
# 11579/11579 - 125s - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.0071 - val_accuracy: 0.9993 - 125s/epoch - 11ms/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.99936
# 11579/11579 - 125s - loss: 0.0058 - accuracy: 0.9990 - val_loss: 0.0042 - val_accuracy: 0.9993 - 125s/epoch - 11ms/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.99936
# 11579/11579 - 126s - loss: 0.0096 - accuracy: 0.9990 - val_loss: 0.0053 - val_accuracy: 0.9992 - 126s/epoch - 11ms/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.99936
# 11579/11579 - 116s - loss: 0.0082 - accuracy: 0.9991 - val_loss: 0.0053 - val_accuracy: 0.9993 - 116s/epoch - 10ms/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.99936
# 11579/11579 - 126s - loss: 0.0063 - accuracy: 0.9990 - val_loss: 0.0043 - val_accuracy: 0.9991 - 126s/epoch - 11ms/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.99936
# 11579/11579 - 125s - loss: 0.0102 - accuracy: 0.9991 - val_loss: 0.0063 - val_accuracy: 0.9993 - 125s/epoch - 11ms/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.99936
# 11579/11579 - 126s - loss: 0.0138 - accuracy: 0.9990 - val_loss: 0.0055 - val_accuracy: 0.9993 - 126s/epoch - 11ms/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.99936
# 11579/11579 - 126s - loss: 0.0056 - accuracy: 0.9991 - val_loss: 0.0051 - val_accuracy: 0.9993 - 126s/epoch - 11ms/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.99936
# 11579/11579 - 125s - loss: 0.0102 - accuracy: 0.9990 - val_loss: 0.0061 - val_accuracy: 0.9991 - 125s/epoch - 11ms/step
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 0.99936
# 11579/11579 - 116s - loss: 0.0098 - accuracy: 0.9990 - val_loss: 0.0047 - val_accuracy: 0.9993 - 116s/epoch - 10ms/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.99936
# 11579/11579 - 118s - loss: 0.0075 - accuracy: 0.9990 - val_loss: 0.0058 - val_accuracy: 0.9992 - 118s/epoch - 10ms/step
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 0.99936
# 11579/11579 - 127s - loss: 0.0085 - accuracy: 0.9990 - val_loss: 0.0072 - val_accuracy: 0.9990 - 127s/epoch - 11ms/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.99936
# 11579/11579 - 118s - loss: 0.0075 - accuracy: 0.9990 - val_loss: 0.0045 - val_accuracy: 0.9990 - 118s/epoch - 10ms/step

# %%
plt.plot(cnn.history.history['accuracy'])
plt.plot(cnn.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(cnn.history.history['loss'])
plt.plot(cnn.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
